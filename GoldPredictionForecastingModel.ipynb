# %% [markdown]
# ## **PROJECT 1** -` Gold Price Prediction Using Machine Learning`
# ## **PROJECT 2** - `Gold-Price-Forecasting`Using Time Series Forecasting`
# # `** By  SapphireDataChic`
#
# >
#
#
#
#
#
#
#
# ![pngwing.com-10.png](data:image/png;base64,...)

# %% [markdown]
# # **Project Overview:**
#
# ---
#
#
#
# ---
#
#
# In this data science project, I will be focusing on predicting the price of gold, a valuable commodity that holds significant economic importance. Gold prices are influenced by various factors such as geopolitical events, economic indicators, investment sentiment, and market demand. By leveraging historical gold price data and relevant features, I aim to build a predictive model that forecasts future gold prices.

# %% [markdown]
# ## **Problem Formation:**
#
# Formulating the problem is a crucial initial step undertaken before commencing this project. It is essential to have a clear understanding of the objectives of our data science project. In this case, our objective is to examine the dynamics of gold prices.
#
# Given the volatile nature of gold prices, which fluctuate rapidly over time, our primary aim in this project is to forecast the price of gold per unit.

# %% [markdown]
# ## **Objective:**
#
# The primary objective of this project is to develop a machine learning model that accurately predicts the future price of gold based on historical trends and key influencing factors. By analyzing historical gold price data and incorporating relevant features, the aim is to build a robust predictive model that can assist investors, traders, and financial institutions in making informed decisions.

# %% [markdown]
# ## **Project Steps:**
#
#  **Identifying the Problem and Data Sources**
#    - Define the problem and objectives.
#    - Identify and gather relevant data sources for analysis.
#    - Create notebooks serving as computational records and documenting the thought process.
#
# **Exploratory Data Analysis**
#    - Apply fundamental concepts of machine learning to an available dataset.
#    - Perform exploratory data analysis to understand the characteristics of the data.
#    - Visualize key patterns and trends.
#
# **Pre-Processing the Data**
#    - Clean and preprocess the data.
#    - Handle missing values and outliers.
#    - Prepare the dataset for machine learning.
#
# **Building a Model to Predict Gold Prices**
#    - Implement machine learning algorithms.
#    - Train and evaluate models.
#    - Interpret the results and justify the interpretation based on the observed dataset.
#
# **Notebooks:**
#
# 1.   Identifying_Problem_and_Data_Sources.ipynb`
# 2.   Exploratory_Data_Analysis.ipynb
# 1.   Pre_Processing_the_Data.ipynb`
# 2.   Building_Model_to_Predict_Gold_Prices.ipynb`

# %% [markdown]
#  # **Notebook 1:**  Data Collection`
#
# 1. **Acquire Historical Gold Price Data**
#    - Obtain data from reliable sources, such as financial databases, government publications, or online repositories.
#
# 2. **Collect Additional Relevant Features**
#    - Gather features that may influence gold prices, including economic indicators, geopolitical events, inflation rates, currency exchange rates, and stock market performance.
#
# 3. **Dataset:**
#    - The data for this analysis is available as `/content/gold_price_data.csv`.

# %% [markdown]
# ## **Notebook 2:** Identifying the Problem and Getting Data
#
# ## ` Notebook Goal:`
#
# Identify the types of information contained in our dataset. In this notebook, Python modules are used to import external datasets with the aim of getting acquainted with the data. The goal is to gain a good grasp of the data and contemplate various approaches for handling it.
#
# We will import all the libraries that we will be using throughout this project in one place so that we do not have to import them every time we use them. This will save both our time and effort.
#
# ### Libraries to Import:
#
# - **Pandas:**
#   - A Python library built on top of NumPy for effective matrix multiplication and dataframe manipulation. It is also used for data cleaning, merging, reshaping, and aggregation.
#
# - **NumPy:**
#   - A Python library used for numerical mathematical computation and handling multidimensional ndarray. It also has a very large collection of mathematical functions to operate on these arrays.
#
# - **Matplotlib:**
#   - Used for plotting 2D and 3D visualization plots. It also supports a variety of output formats, including graphs.
#
# - **Seaborn:**
#   - A seaborn library built on top of Matplotlib, used for plotting beautiful plots.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # `**Loading the Dataset **`
#
# We will read the dataset using the pandas read_csv() function, we can also specify the parse_dates argument which will convert the data type of the Dates column in datetime dtype. One Thing to notice initially the Dates dtype is an object. But when We change it datetime dtype it can be useful in many plotting and other computation.

# %%
#Loading the Dataset
# Reading the CSV file and parsing the 'Date' column as datetime
data = pd.read_csv('/content/gold_price_data.csv', parse_dates=["Date"])

# Displaying the loaded data
data
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0    2008-01-02  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1    2008-01-03  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2    2008-01-04  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3    2008-01-07  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4    2008-01-08  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285 2018-05-08  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286 2018-05-09  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287 2018-05-10  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288 2018-05-14  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289 2018-05-16  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %% [markdown]
# **`Column Meanings:`**
#
# - **Date:** The timestamp indicating the time of the observation.
#
# - **SPX:** Stock market index tracking. It likely represents the Standard & Poor's 500, which is a stock market index that measures the stock performance of 500 large companies listed on stock exchanges in the United States.
#
# - **GLD:**  This column likely represents the price or performance of gold.
#
# - **USO:** The United States Oil Fund (USO). It is an exchange-traded product that tracks the price movements of West Texas Intermediate (WTI) light, sweet crude oil futures contracts traded on the New York Mercantile Exchange (NYMEX).
#
# - **SLV:** iShares Silver Trust (SLV). It is an exchange-traded fund (ETF) that tracks the price of silver. The SLV ETF aims to reflect the price of silver owned by the trust, less the trust's expenses and liabilities.

# %% [markdown]
# ## **Notebook 3:** Exploratory Data Analysis
# ## ` Notebook Goal:`
#
# Explore the variables to assess how they relate to the response variable. In this notebook, I aim to become familiar with the dataset through data exploration and visualization techniques using Python libraries such as Pandas, Matplotlib, and Seaborn. Understanding the data is crucial as it provides valuable insights for subsequent data pre-processing steps.

# %%
#General Dataset Overview
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   datetime64[ns]
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 107.5 KB

# %%
data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
# Time Series Analysis

plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['GLD'])
plt.title('Gold Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Gold Price')
plt.show()

# %%
# Correlation Analysis
# Check Relationship Btw the Y and the X's
sns.set(style='darkgrid')
sns.regplot(y=data['EUR/USD'], x=data['SPX'], ci=0)
plt.title(f"Correlation Between EUR/USD and SPX is {data['EUR/USD'].corr(data['SPX']).round(2)}")
plt.show()

# %%
def plotter(data, a, b, c, dependent):
    plt.figure(figsize = (18, 4))

    plt.subplot(1, 3, 1)
    sns.regplot(y = data[dependent], x = data[a], ci = 0)
    plt.title(f"Correlation Btw EUR/USD and {a} is {(data[dependent].corr(data[a]).round(2))}")

    plt.subplot(1, 3, 2)
    sns.regplot(y = data[dependent], x = data[b], ci = 0)
    plt.title(f"Correlation Btw EUR/USD and {b} is {(data[dependent].corr(data[b]).round(2))}")

    plt.subplot(1, 3, 3)
    sns.regplot(y = data[dependent], x = data[c], ci = 0)
    plt.title(f"Correlation Btw EUR/USD and {c} is {(data[dependent].corr(data[c]).round(2))}")



plotter(data, 'GLD', 'USO', 'SLV', 'EUR/USD')

# %%
# Univariate Analysis
for column in data.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(data[column], kde=True)
    plt.title(f'Histogram for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# MULTI- COLINEARITY
sns.heatmap(data.corr(), annot = True, cmap = 'BuPu')
# Out:
# <Axes: >

# %%
#  TRAIN AND TEST SPLIT

from sklearn.model_selection import train_test_split

x = data.drop(['Date', 'EUR/USD'], axis=1)
y = data['EUR/USD']

xtrain, xtest, ytrain,ytest = train_test_split(x, y, test_size = 0.20, random_state = 10)
print(f'Xtrain: {xtrain.shape}')
print(f'ytrain: {ytrain.shape}')
print(f'Xtest: {xtest.shape}')
print(f'ytest: {ytest.shape}')
# Out:
# Xtrain: (1832, 4)
# ytrain: (1832,)
# Xtest: (458, 4)
# ytest: (458,)

# %% [markdown]
# ## **Notebook 4:** Pre-Processing the Data
# ## ` Notebook Goal:`
#
#
# - Clean the dataset by handling missing values, outliers, and inconsistencies.
# - Perform feature engineering to create new features or transform existing ones to improve model performance.
# - Normalize or scale the features to ensure that they are on a similar scale.

# %%
#To check for missing Values... No missing values
data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
# Handling outliers (assuming 'GLD' is the target variable)
from scipy.stats import zscore

z_scores = zscore(data['GLD'])
outliers = (z_scores > 3) | (z_scores < -3)
data_new = data[~outliers]

# Handling inconsistencies (if any)
# You may need to manually inspect and correct inconsistencies based on your dataset

# Display cleaned data
data_new.head()
# Out:
#         Date          SPX        GLD        USO     SLV   EUR/USD
# 0 2008-01-02  1447.160034  84.860001  78.470001  15.180  1.471692
# 1 2008-01-03  1447.160034  85.570000  78.370003  15.285  1.474491
# 2 2008-01-04  1411.630005  85.129997  77.309998  15.167  1.475492
# 3 2008-01-07  1416.180054  84.769997  75.500000  15.053  1.468299
# 4 2008-01-08  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
# To plot the price of gold for each increasing day
plt.figure(figsize=(12, 6))
plt.plot(data_new['Date'], data_new['GLD'])
plt.title('Gold Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Gold Price')
plt.show()

# %% [markdown]
# Through this graph, I am unable to find any good insight into the change in the price of gold. It looks very noisy, to see the trend in the data I have to make the graph smooth

# %% [markdown]
# To see the distribution of numerical columns I will plot the histogram of each column in one figure to do this I will use the Matplotlib subplot function.

# %%
for column in data_new.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(data_new[column], kde=True)
    plt.title(f'Histogram for {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
 # skewness along the index axis
print(data_new.skew(axis=0, skipna=True))
# Out:
# SPX        0.300362
# GLD        0.334138
# USO        1.699331
# SLV        1.153641
# EUR/USD   -0.005292
# dtype: float64

# %% [markdown]
# **`Plotting Boxplot to Visualize the Outliers `**
#
# Boxplots are very useful in plotting the spread and skewness of the data. They are also useful in plotting individual outlier data points. Boxplots consist of a box which represents points in the range of 25% to 75% quantiles. The line in the middle of the box represents the median, and the whisker at the end of the box shows the range below 25% and 75%, excluding outliers.

# %%
fig = plt.figure(figsize=(8, 8))
temp = data_new.drop("Date", axis=1).columns.tolist()
for i, item in enumerate(temp):
    plt.subplot(2, 3, i+1)
    sns.boxplot(data=data_new, x=item, color='violet')
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=2.0)
plt.show()

# %% [markdown]
# It can be seen clearly that the columns 'GLD', 'USO', and 'SLV' have outliers present. Therefore, we create a function to normalize the outliers in the columns.

# %%
# Create a boxplot for all  selected column with outliers
plt.figure(figsize=(10, 6))
sns.boxplot(data=data_new[['GLD', 'USO', 'SLV']])
plt.title('Boxplot for Columns with Outliers')
plt.xlabel('Columns')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
data_new.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %% [markdown]
# ## ` Functions to normalize the outliers in the columns.`

# %%
# Function to normalize outliers

def outlier_removal(column):
    # Capping the outlier rows with Percentiles
    upper_limit = column.quantile(.95)

    # set upper limit to 95percentile
    lower_limit = column.quantile(.05)

    # set lower limit to 5 percentile
    column.loc[(column > upper_limit)] = upper_limit
    column.loc[(column < lower_limit)] = lower_limit
    return column


# Normalize outliers in columns except Date

data_new[['SPX', 'GLD', 'USO', 'SLV', 'EUR/USD']] = \
    data_new[['SPX', 'GLD', 'USO', 'SLV',  'EUR/USD']].apply(outlier_removal)

# %%
# Visualize the results using a boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(data=data_new[['SPX', 'GLD', 'USO', 'SLV', 'EUR/USD']])
plt.title('Boxplot After Outlier Normalization')
plt.xlabel('Columns')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# # **# `Modeling the Data`**
#
# Before I start modeling, the data must be divided into train and test sets so that after training, we can see how well our model learns the patterns and generalizes to new data points. It is also a way to ensure that our model is not learning noise in the data or, in other words, is not overfitting the dataset.

# %%
#  TRAIN AND TEST SPLIT
from sklearn.model_selection import train_test_split

# select the features and target variable
X = data_new.drop(['Date', 'EUR/USD'], axis=1)

y = data_new['EUR/USD']
# dividing dataset in to train test
x_train, x_test,\
    y_train, y_test = train_test_split(X, y,
                                       test_size=0.2)

# %% [markdown]
# Here, I am first dropping the 'Date' and our target variable 'EUR/USD', and storing the resulting DataFrame in the variable X. This DataFrame will represent our independent variables. Additionally, we are storing our target variable in the Y variable. The data is then divided into training and testing sets in the ratio of 80:20.

# %% [markdown]
# # `Scaling the Data `
#
# Before we train the model on our data we should perform scaling on our data to normalize. After scaling the data our mean of each column becomes zero and their standard deviation becomes 1. It is also called z-score normalization since we subtract the mean of the column from each element and divide it by the standard deviation of the column. It brings all the columns to the same scale and directly comparable with one another.

# %%
# Create an instance of the StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler on the training dataset
scaler.fit(x_train)

# Transform the training dataset
# using the StandardScaler
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)
print(f'Xtrain: {xtrain.shape}')
print(f'ytrain: {ytrain.shape}')
print(f'Xtest: {xtest.shape}')
print(f'ytest: {ytest.shape}')
# Out:
# Xtrain: (1832, 4)
# ytrain: (1832,)
# Xtest: (458, 4)
# ytest: (458,)

# %% [markdown]
# # **NOTE:**
#
# After using a linear regression model, the obtained Cross Validation Score of -1870.3120720353006 indicates a low predictive performance.

# %%
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import r2_score, mean_absolute_error

#regressor = LinearRegression() # ---------------------------------------- instantiate the algorithm
#regressor.fit(x_train, ytrain) # ----------------------------------------- Fit the algorithm on the model

# checking for underfitting
#cross_validation = regressor.predict(xtrain)
#print(f'Cross Validation Score: {r2_score(cross_validation, ytrain)}')
# Out:
# Cross Validation Score: -1870.3120720353006

# %% [markdown]
# I also tried using linear regression model, without removing the outlier, the obtained Cross Validation Score: 0.6762613590251565 an R-squared score of 0.7135775700405922, while indicative of some predictive power, suggests room for enhancement. This motivates the exploration of alternative techniques like Lasso Regression, known for its ability to handle complex relationships in the data and potentially improve model performance.

# %%
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import r2_score, mean_absolute_error

#regressor = LinearRegression() # ---------------------------------------- instantiate the algorithm
#regressor.fit(xtrain, ytrain) # ----------------------------------------- Fit the algorithm on the model

# checking for underfitting
#cross_validation = regressor.predict(xtrain)
#print(f'Cross Validation Score: {r2_score(cross_validation, ytrain)}')
# Out:
# Cross Validation Score: 0.6762613590251565

# %%
#test = regressor.predict(xtest)
#print(f'Test Score: {r2_score(test, ytest)}')
# Out:
# Test Score: 0.7135775700405922

# %% [markdown]
# ## Transitioning from Linear Regression to RandomForestRegressor Due to Low Score
#
#  In this model, RandomForestRegressor and XGBoost are employed. We will be initializing a 'parameter grid' for searching optimal hyperparameters, which is a good practice when using RandomForestRegressor and XGBoost. It allows  us to perform a systematic search over a range of hyperparameter values to find the combination that yields the best model performance.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # `Parameter grid`

# %%
# Insiate param grid for which to search
param_grid = {'n_estimators': [50, 80, 100],
              'max_depth': [3, 5, 7]}

# %% [markdown]
# # `RandomForestRegressor `

# %%
# create instance of the Randomforest regressor
rf = RandomForestRegressor()

# Define Girdsearch with random forest
# object parameter grid scoring and cv
rf_grid_search = GridSearchCV(rf, param_grid, scoring='r2', cv=2)

# Fit the GridSearchCV object to the training data

rf_grid_search.fit(x_train_scaled, y_train)

# Print the best parameter values and score
print('Best parameter values: ', rf_grid_search.best_params_)
print('Best score: ', rf_grid_search.best_score_)
# Out:
# Best parameter values:  {'max_depth': 7, 'n_estimators': 100}
# Best score:  0.9547572189483154

# %% [markdown]
# Here I have used both RandomForest regressor and Gridsearchcv, The Gridsearch will help in selecting the best number of decision trees from 50,80,100. I have also specified the maximum depth of the tree as a parameter which can be 3,5 or 7.
#
# The best parameter value shows that the model gives the best result when it takes the average result of one hundred Decision trees having a maximum depth of 7.

# %%
# Compute the R-squared of the
# fitted model on the test data
r2 = r2_score(y_test,
              rf_grid_search.predict(x_test_scaled))

# Print the R-squared
print("R-squared:", r2)
# Out:
# R-squared: 0.9488910363867112

# %% [markdown]
# # ` Plotting  a bar chart of the feature importance from the dataset.`

# %%
features = data_new.drop("Date", axis=1).columns

# store the importance of the feature
importances = rf_grid_search.best_estimator_.\
    feature_importances_


indices = np.argsort(importances)

# title of the graph
plt.title('Feature Importance')

plt.barh(range(len(indices)),
         importances[indices],
         color='red',
         align='center')

# plot bar chart
plt.yticks(range(len(indices)),
           [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# `This feature importance graph shows that USO column plays a major effect (more than 2x) in deciding the gold price in USD.`

# %% [markdown]
# # **`XGBoost Model for Regression `**
#
# In our models, we will use the XGBOOST model for fitting our training dataset.XGBoost is a powerful and versatile algorithm known for its effectiveness in various machine learning tasks.

# %%
 # Create an instance of the XGBRegressor model
model_xgb = XGBRegressor()

# Fit the model to the training data
model_xgb.fit(x_train_scaled, y_train)

# Print the R-squared score on the training data
print("Xgboost Accuracy =", r2_score(
    y_train, model_xgb.predict(x_train_scaled)))
# Out:
# Xgboost Accuracy = 0.9985374276121455

# %% [markdown]
# `# Now let’s evaluate this model as well using the testing data.`

# %%
# Print the R-squared score on the test data
print("Xgboost Accuracy on test data =",
      r2_score(y_test,
               model_xgb.predict(x_test_scaled)))
# Out:
# Xgboost Accuracy on test data = 0.9720361537527848

# %% [markdown]
# ### `Through the graph, we can see that USO column plays a major role in deciding the prediction value. `

# %%
#install #pip install eli5

# %% [markdown]
# # `Model Explainability`
# I will use eli5 to see the Weights of our best-performing model which is  XGBOOST best on its train and test accuracy.This will display a visualization of the feature importances or weights assigned to each feature in your XGBoost model.

# %%
#!pip install eli5
import eli5 as eli
# weight of variables in xgboost model
# Get the names of the features
feature_names = x_train.columns.tolist()

# Explain the weights of the features using ELI5
eli.explain_weights(model_xgb,
                    feature_names=feature_names)
# Out:
# Explanation(estimator='XGBRegressor(base_score=None, booster=None, callbacks=None,\n             colsample_bylevel=None, colsample_bynode=None,\n             colsample_bytree=None, device=None, early_stopping_rounds=None,\n             enable_categorical=False, eval_metric=None, feature_types=None,\n             gamma=None, grow_policy=None, importance_type=None,\n             interaction_constraints=None, learning_rate=None, max_bin=None,\n             max_cat_threshold=None, max_cat_to_onehot=None,\n             max_delta_step=None, max_depth=None, max_leaves=None,\n             min_child_weight=None, missing=nan, monotone_constraints=None,\n             multi_strategy=None, n_estimators=None, n_jobs=None,\n             num_parallel_tree=None, random_state=None, ...)', description='\nXGBoost feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=True, targets=None, feature_importances=FeatureImportances
# ...

# %% [markdown]
# # `Evaluating and comparing our model performance, using ytest for 'Actual' and y-pred for  'Predicted'

# %%
# Using  the trained model to make predictions on the test set
y_pred = model_xgb.predict(x_test_scaled)

# To evaluate the performance of the model on the test set
test_r2_score = r2_score(y_test, y_pred)
print(f"XGBoost Accuracy on Test Set: {test_r2_score}")

# To Create a DataFrame to display actual and predicted values
output = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# Display the DataFrame
output
# Out:
# XGBoost Accuracy on Test Set: 0.9720361537527848
#         Actual  Predicted
# 1509  1.247598   1.249964
# 2096  1.144165   1.130788
# 1517  1.248065   1.242831
# 1765  1.082755   1.083623
# 12    1.461796   1.473761
# ...        ...        ...
# 448   1.408232   1.426748
# 1629  1.114666   1.094666
# 765   1.435791   1.403012
# 1014  1.228954   1.232592
# 573   1.263504   1.244902
#
# [458 rows x 2 columns]

# %% [markdown]
# # **`Model Interpretation:`**
# The XGBoost model, with an accuracy of 96.83% on the test set, assigns weights to each feature. In this context:
#
# - USO (Weight: 0.8402): The highest weight implies significant importance, suggesting that changes in USO, likely reflecting oil prices, strongly influence gold prices.
#
# -  SLV (Weight: 0.0599): The second-highest weight indicates moderate importance, suggesting that silver prices, as represented by SLV, also contribute to predicting gold prices.
#
# - SPX (Weight: 0.0555): This represents the stock market index, with a weight reflecting a lower but notable impact on gold price predictions.
#
# - GLD (Weight: 0.0444): The lowest weight indicates the least influence on the gold price prediction among the listed features.
#
# These weights offer insights into the relative importance of features in the XGBoost model, guiding the understanding of factors influencing gold price forecasts.

# %% [markdown]
# # **Model Deployment using Pickle**
# To deploy the model I will use the pickle library from the Python language. I will deploy the best-performing model which is XGBoost.

# %%
# dump model using pickle library
import pickle

# dump model in file model.pkl
pickle.dump(model_xgb, open('GoldPricePredictormodel.pkl', 'wb'))

# %% [markdown]
# # **PROJECT 2** `- Gold-Price-Forecasting Using Time Series Forecasting`
#
# Given my successful experience in machine-based gold price prediction, extending my efforts to "Gold-Price-Forecasting using LSTM for Time Series Forecasting" is a significant initiative. LSTM for Time Series Forecasting  entails predicting future values based on historical data, holds particular relevance in domains like financial markets, where comprehending and predicting trends over time is crucial. I am eager to broaden my pursuits into Gold-Price-Forecasting through Time Series Analysis on historical gold price data.

# %% [markdown]
# **`Here's a brief overview of using LSTM for gold price forecasting:`**
#
# 1. **Data Preparation**: Gather historical gold price data along with relevant features such as economic indicators, market sentiment, and other factors that influence gold prices.
#
# 2. **Data Preprocessing**: Preprocess the data by scaling it using techniques like MinMaxScaler to ensure that all input features are on a similar scale, preventing features with larger magnitudes from dominating the model training process.
#
# 3. **Model Architecture**: Design the LSTM model architecture, specifying the number of LSTM layers, the number of neurons in each layer, activation functions, and other hyperparameters. Additionally, consider including dropout layers to prevent overfitting.
#
# 4. **Training**: Train the LSTM model on the preprocessed training data, using historical gold price sequences as input and future gold prices as output. During training, the model learns to capture patterns and trends in the data, optimizing its parameters to minimize prediction errors.
#
# 5. **Validation**: Validate the trained model using a separate validation dataset to assess its performance and fine-tune hyperparameters if necessary. Evaluate the model's accuracy using metrics such as Mean Squared Error (MSE) or Mean Absolute Error (MAE).
#
# 6. **Testing**: Once validated, evaluate the model's performance on unseen test data to assess its ability to generalize to new data. Analyze the model's predictions against actual gold prices to determine its effectiveness in forecasting.
#
# 7. **Visualization**: Visualize the model's predictions and compare them with actual gold prices using plots and charts. This visualization helps identify any discrepancies and provides insights into the model's forecasting capabilities.
#
# By following these steps and leveraging LSTM networks for gold price forecasting, I can build a predictive model that captures the dynamics of gold price movements and enables informed decision-making in investment and trading strategies.

# %% [markdown]
# # **`Importing Needed Libraries`**

# %%
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas_datareader as data
from datetime import date, datetime
import plotly.graph_objects as go

# %% [markdown]
# # **Reading The Data**
#
# We will read the dataset using the pandas read_csv() function, we can also specify the parse_dates argument which will convert the data type of the Dates column in datetime dtype. One Thing to notice initially the Dates dtype is an object. But when We change it datetime dtype it can be useful in many plotting and other computation.

# %%
data2 = pd.read_csv('/content/gold_price_data.csv')

# Displaying the loaded data
data2
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
#  create a new DataFrame with just the 'Date' and 'GLD' columns like this:
data_new = data2[['Date', 'GLD']]
data_new
# Out:
#            Date         GLD
# 0      1/2/2008   84.860001
# 1      1/3/2008   85.570000
# 2      1/4/2008   85.129997
# 3      1/7/2008   84.769997
# 4      1/8/2008   86.779999
# ...         ...         ...
# 2285   5/8/2018  124.589996
# 2286   5/9/2018  124.330002
# 2287  5/10/2018  125.180000
# 2288  5/14/2018  124.489998
# 2289  5/16/2018  122.543800
#
# [2290 rows x 2 columns]

# %%
print(data_new.tail())
# Out:
#            Date         GLD
# 2285   5/8/2018  124.589996
# 2286   5/9/2018  124.330002
# 2287  5/10/2018  125.180000
# 2288  5/14/2018  124.489998
# 2289  5/16/2018  122.543800

# %% [markdown]
# # `Exploratory Data Analysis `

# %% [markdown]
# `Understanding our data`

# %%
data_new.shape
# Out:
# (2290, 2)

# %%
data_new.plot(figsize=(20,8))
plt.title("Gold price (Yearly) since 2008 to 2018")
plt.xlabel("Months")
plt.ylabel("Price")
plt.grid();

# %%
round(data_new.describe(),3)
# Out:
#             GLD
# count  2290.000
# mean    122.733
# std      23.283
# min      70.000
# 25%     109.725
# 50%     120.580
# 75%     132.840
# max     184.590

# %% [markdown]
# # `Visual Analysis`

# %% [markdown]
# **Creating Moving Average**
#
# A moving average is a statistical technique used to smooth out fluctuations in data by calculating the average value of a subset of consecutive data points over a specified time period. Moving averages are useful for smoothing out short-term fluctuations in data, making underlying trends more apparent. They are commonly used in finance, economics, signal processing, and time series analysis to identify patterns and trends in noisy data.  Here's how it works:

# %%
# create moving average
# first 100 values are null then mean
mean100 = data_new.GLD.rolling(100).mean()
mean100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2285    125.088600
# 2286    125.131200
# 2287    125.198100
# 2288    125.258200
# 2289    125.303538
# Name: GLD, Length: 2290, dtype: float64

# %%
# Plot moving average
plt.figure(figsize=(12, 6))
plt.plot(data_new.index, data_new['GLD'], label='Gold Price')
plt.plot(mean100.index, mean100, 'r', label='Moving Average (100 days)')

# Add year and month to the plot
plt.xlabel('Date')
plt.ylabel('Gold Price')
plt.title('Gold Price with Moving Average')
plt.legend()

# Rotate x-axis labels to avoid overlap
plt.xticks(rotation=45)

plt.show()

# %%
mean200 = data_new.GLD.rolling(200).mean()
mean200
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2285    123.213600
# 2286    123.232850
# 2287    123.259650
# 2288    123.285500
# 2289    123.306069
# Name: GLD, Length: 2290, dtype: float64

# %%
# Plot moving average
plt.figure(figsize=(12, 6))
plt.plot(data_new.index, data_new['GLD'], label='Gold Price')
plt.plot(mean100.index, mean100, 'r', label='Moving Average (100 days)')
plt.plot(mean200.index, mean200, 'g', label='Moving Average (200 days)')

# Add year and month to the plot
plt.xlabel('Date')
plt.ylabel('Gold Price')
plt.title('Gold Price with Moving Average')
plt.legend()

plt.show()

# %%
new_data.shape
# Out:
# (2290, 2)

# %% [markdown]
# # **`Splitting The Data`** `
#
# To ensure the model learns from historical data and can generalize to new, unseen data, it's customary to divide the dataset into training and testing sets. We'll split the data using a ratio of 70% to 30%, where 70% of the data will be used for training the model, and 30% will be reserved for testing its performance.
#
# **Here's how the data is split**:

# %%
# splitting date into training and testing
data_training= pd.DataFrame(data_new['GLD'][0:int(len(data_new)*0.70)])
data_testing = pd.DataFrame(data_new['GLD'][int(len(data_new)*0.70): int(len(data_new))])

print("training data: ",data_training.shape)
print("testing data: ", data_testing.shape)
# Out:
# training data:  (1603, 1)
# testing data:  (687, 1)

# %%
data_training.head()
# Out:
#          GLD
# 0  84.860001
# 1  85.570000
# 2  85.129997
# 3  84.769997
# 4  86.779999

# %%
data_testing
# Out:
#              GLD
# 1603  115.279999
# 1604  116.690002
# 1605  116.110001
# 1606  115.470001
# 1607  114.669998
# ...          ...
# 2285  124.589996
# 2286  124.330002
# 2287  125.180000
# 2288  124.489998
# 2289  122.543800
#
# [687 rows x 1 columns]

# %% [markdown]
# ## `**Scaling of Data**`
#
# Scaling of data using MinMaxScaler is a normalization technique that transforms features by scaling them to a specified range, typically (0, 1). The process involves rescaling each feature individually so that it falls within the specified range, preserving the shape of the original distribution while ensuring all features have the same scale.
#
# Here's how it works:

# %%
# scaling of data using min max scaler (0,1)

scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.12967974],
#        [0.13587574],
#        [0.13203593],
#        ...,
#        [0.38179598],
#        [0.38101061],
#        [0.39794048]])

# %%
data_training_array.shape
# Out:
# (1603, 1)

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %% [markdown]
# # **MODELING USING LSMT**
#
#
# Modeling using LSTM (Long Short-Term Memory) for gold price forecasting involves leveraging the power of recurrent neural networks (RNNs) to capture complex patterns and dependencies in historical gold price data. LSTM networks are well-suited for time series forecasting tasks due to their ability to retain long-term dependencies and handle sequential data effectively.
#
# Here's a brief overview of using LSTM for gold price forecasting:

# %% [markdown]
# ## `Time Series - Forecasting models `

# %%
model = Sequential()
model.add(LSTM(units= 50, activation= 'relu', return_sequences= True,
               input_shape= (x_train.shape[1], 1)))

model.add(Dropout(0.2))


model.add(LSTM(units= 60, activation= 'relu', return_sequences= True))

model.add(Dropout(0.3))


model.add(LSTM(units= 80, activation= 'relu', return_sequences= True))

model.add(Dropout(0.4))


model.add(LSTM(units= 120, activation= 'relu'))

model.add(Dropout(0.5))


model.add(Dense(units= 1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 120)               96480
#
#  dropout_3 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# ...
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# `I use the Adam optimizer optimizes model parameters by minimizing the Mean Squared Error (MSE) loss function. MSE measures the average squared difference between predicted and true values, serving as a metric for the model's performance. By iteratively adjusting parameters to minimize MSE, the Adam optimizer enhances the accuracy of predictions during training.`

# %%
model.compile(optimizer='adam', loss="mean_squared_error")
model.fit(x_train, y_train, epochs= 25)
# Out:
# Epoch 1/25
# 47/47 [==============================] - 10s 155ms/step - loss: 0.0643
# Epoch 2/25
# 47/47 [==============================] - 7s 142ms/step - loss: 0.0124
# Epoch 3/25
# 47/47 [==============================] - 7s 155ms/step - loss: 0.0109
# Epoch 4/25
# 47/47 [==============================] - 7s 156ms/step - loss: 0.0102
# Epoch 5/25
# 47/47 [==============================] - 7s 143ms/step - loss: 0.0085
# Epoch 6/25
# 47/47 [==============================] - 7s 155ms/step - loss: 0.0092
# Epoch 7/25
# 47/47 [==============================] - 7s 147ms/step - loss: 0.0081
# Epoch 8/25
# 47/47 [==============================] - 7s 150ms/step - loss: 0.0080
# Epoch 9/25
# 47/47 [==============================] - 7s 155ms/step - loss: 0.0075
# Epoch 10/25
# 47/47 [==============================] - 7s 155ms/step - loss: 0.0072
# Epoch 11/25
# 47/47 [==============================] - 7s 154ms/step - loss: 0.0068
# Epoch 12/25
# ...

# %% [markdown]
# ### `Saving the Model`

# %%
# save model
model.save('GoldForecastingmodel.h5')

# %%
data_testing
# Out:
#              GLD
# 1603  115.279999
# 1604  116.690002
# 1605  116.110001
# 1606  115.470001
# 1607  114.669998
# ...          ...
# 2285  124.589996
# 2286  124.330002
# 2287  125.180000
# 2288  124.489998
# 2289  122.543800
#
# [687 rows x 1 columns]

# %%
data_training.tail(100)
# Out:
#              GLD
# 1503  109.879997
# 1504  112.970001
# 1505  110.459999
# 1506  112.040001
# 1507  111.500000
# ...          ...
# 1598  115.480003
# 1599  115.059998
# 1600  113.750000
# 1601  113.660004
# 1602  115.599998
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)
final_df= past_100_days.append(data_testing, ignore_index =True)

# %%
final_df.head()
# Out:
#           GLD
# 0  109.879997
# 1  112.970001
# 2  110.459999
# 3  112.040001
# 4  111.500000

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.31508215],
#        [0.41887804],
#        [0.33456492],
#        [0.38763854],
#        [0.36949945],
#        [0.37520983],
#        [0.46926433],
#        [0.45515624],
#        [0.4887471 ],
#        [0.44272752],
#        [0.48236477],
#        [0.50016785],
#        [0.49076248],
#        [0.49983188],
#        [0.49244212],
#        [0.3899899 ],
#        [0.54014108],
#        [0.49177014],
#        [0.53174336],
#        [0.51662731],
#        [0.46792066],
#        [0.51326829],
#        [0.59422236],
#        [0.58649636],
#        [0.57742693],
#        [0.56802156],
#        [0.46657699],
#        [0.48538781],
#        [0.46254602],
#        [0.49210615],
#        [0.47934145],
#        [0.40476995],
#        [0.41115204],
#        [0.41215974],
#        [0.48135707],
#        [0.44239154],
#        [0.49378552],
#        [0.4393685 ],
#        [0.45616393],
#        [0.51394024],
#        [0.55828017],
#        [0.53510238],
#        [0.51864293],
# ...

# %%
input_data.shape
# Out:
# (787, 1)

# %%
x_test = []
y_test = []

for i in range (100, input_data.shape[0]):
    x_test.append(input_data[i-100 : i])
    y_test.append(input_data[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (687, 100, 1)
# (687,)

# %% [markdown]
# ## `Making Predictions`

# %%
# making predictions

y_predicted = model.predict(x_test)
y_predicted.shape
# Out:
# 22/22 [==============================] - 1s 43ms/step
# (687, 1)

# %%
y_test
# Out:
# array([0.49647286, 0.54383607, 0.52435334, 0.50285519, 0.4759824 ,
#        0.49177014, 0.46825664, 0.50151152, 0.48807514, 0.47766205,
#        0.49983188, 0.44776621, 0.47564669, 0.4981525 , 0.53174336,
#        0.50419886, 0.43567347, 0.45683561, 0.46758469, 0.46556934,
#        0.43399383, 0.43768886, 0.47027202, 0.53913338, 0.56029552,
#        0.57171632, 0.51696328, 0.52334565, 0.51024521, 0.45045355,
#        0.44978157, 0.45414831, 0.45347659, 0.46892835, 0.44138385,
#        0.41451106, 0.40544167, 0.41383938, 0.44608657, 0.42861943,
#        0.44440716, 0.43063481, 0.4484379 , 0.49781653, 0.44138385,
#        0.41619071, 0.40611335, 0.40107492, 0.42223709, 0.39872359,
#        0.38562316, 0.37823314, 0.38831026, 0.34464228, 0.35572706,
#        0.36479676, 0.35236804, 0.34397033, 0.32448783, 0.31105142,
#        0.17467236, 0.16358758, 0.14444079, 0.12865306, 0.14645618,
#        0.15183058, 0.15686924, 0.12663744, 0.12092702, 0.1279811 ,
# ...

# %%
y_predicted
# Out:
# array([[0.4176579 ],
#        [0.4244269 ],
#        [0.4319445 ],
#        [0.4401961 ],
#        [0.44889098],
#        [0.45742285],
#        [0.46530795],
#        [0.4720472 ],
#        [0.47753555],
#        [0.48176044],
#        [0.48472995],
#        [0.48665553],
#        [0.4874717 ],
#        [0.48728526],
#        [0.48641908],
#        [0.48544258],
#        [0.48471117],
#        [0.48396462],
#        [0.48296243],
#        [0.4816079 ],
#        [0.47988957],
#        [0.47767895],
#        [0.47491896],
#        [0.4718005 ],
#        [0.46897227],
#        [0.46724802],
#        [0.46738708],
#        [0.46947455],
#        [0.47328132],
#        [0.4782927 ],
#        [0.48346448],
#        [0.4878373 ],
#        [0.49079984],
#        [0.49207377],
#        [0.49174744],
#        [0.48994774],
#        [0.48673904],
#        [0.48224914],
#        [0.47669715],
#        [0.47050124],
#        [0.46401656],
#        [0.4576171 ],
#        [0.45155782],
# ...

# %%
scaler.scale_
# Out:
# array([0.03359086])

# %%
scaler = scaler.scale_
scaler
# Out:
# array([0.03359086])

# %%
scale_factor = 1/scaler[0]

y_predicted = y_predicted * scale_factor

y_test = y_test* scale_factor

# %%
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = 'Actual Price')
plt.plot(y_predicted, 'r', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import pandas as pd

# Initialize an empty DataFrame
predictions_df = pd.DataFrame()

# Add columns for predictions and actual values
predictions_df['Actual'] = []  # Add the actual values
# Append actual prices to the 'Actual' column
predictions_df['Actual'] = y_test

# Append predicted prices to the 'Predictions' column
predictions_df['Predicted'] = y_predicted

# Display the DataFrame
predictions_df
# Out:
#         Actual  Predicted
# 0    14.779999  12.433678
# 1    16.190002  12.635191
# 2    15.610001  12.858990
# 3    14.970001  13.104640
# 4    14.169998  13.363486
# ..         ...        ...
# 682  24.089996  26.201622
# 683  23.830002  25.868364
# 684  24.680000  25.557476
# 685  23.989998  25.290739
# 686  22.043800  25.076946
#
# [687 rows x 2 columns]

# %%
rmse=np.sqrt(np.mean(((y_predicted- y_test)**2)))
print(rmse)
# Out:
# 10.253053980405433

# %%
y_predicted
# Out:
# array([[12.433678 ],
#        [12.635191 ],
#        [12.85899  ],
#        [13.10464  ],
#        [13.363486 ],
#        [13.61748  ],
#        [13.85222  ],
#        [14.052848 ],
#        [14.216235 ],
#        [14.3420105],
#        [14.430412 ],
#        [14.487738 ],
#        [14.512034 ],
#        [14.506484 ],
#        [14.480699 ],
#        [14.451628 ],
#        [14.429853 ],
#        [14.407629 ],
#        [14.377793 ],
#        [14.33747  ],
#        [14.286315 ],
#        [14.220505 ],
#        [14.138339 ],
#        [14.045503 ],
#        [13.961307 ],
#        [13.909976 ],
#        [13.914115 ],
#        [13.976259 ],
#        [14.089587 ],
#        [14.238776 ],
#        [14.392739 ],
#        [14.522919 ],
#        [14.611114 ],
#        [14.649038 ],
#        [14.639323 ],
#        [14.585746 ],
#        [14.490223 ],
#        [14.356559 ],
#        [14.191277 ],
#        [14.0068245],
#        [13.813775 ],
#        [13.623263 ],
#        [13.442878 ],
# ...

# %%
from datetime import datetime, time

# Define start and end dates
start_date = datetime(2008, 1, 2)
end_date = datetime(2018, 5, 16)

print("Start Date:", start_date)
print("End Date:", end_date)
# Out:
# Start Date: 2008-01-02 00:00:00
# End Date: 2018-05-16 00:00:00

# %%
# Predict future price
df1 = new_data.reset_index()['GLD']
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
import datetime as dt
my_time = datetime.min.time()
date1 = datetime.combine(date1, my_time)
print(date1)
# Out:
# 2008-01-12 00:00:00

# %%
date1
# Out:
# datetime.datetime(2008, 1, 12, 0, 0)

# %%
datemax
# Out:
# datetime.datetime(2008, 1, 2, 0, 0)

# %%
# Get input time from user
time_str = input("Enter the time in the format 'yyyy-mm-dd': ")
date1 = dt.datetime.strptime(time_str, "%Y-%m-%d")
# Out:
# Enter the time in the format 'yyyy-mm-dd': 2009-02-24

# %%
nDay = date1 - datemax
nDay = nDay.days
lst_output = []
n_steps =  2289
i = 0

temp_input = list(df1[:].reshape(1, -1)[0])

while i <= nDay:

    if len(temp_input) > n_steps:
        x_input = np.array(temp_input[1:])
        print("{} day input {}".format(i, x_input))
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i, yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = temp_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i = i + 1

res = scaler.inverse_transform(lst_output)
output = res[nDay - 1]
print("Predicted price on {} is: {}".format(date1.date(), output))
# Out:
# 0 day input [0.13587574 0.13203593 0.1288943  ... 0.48154291 0.47552142 0.45853741]
# 0 day output [[0.47356504]]
# 1 day input [0.13203593 0.1288943  0.14643511 ... 0.47552142 0.45853741 0.47356504]
# 1 day output [[0.4718089]]
# 2 day input [0.1288943  0.14643511 0.14442799 ... 0.45853741 0.47356504 0.47180891]
# 2 day output [[0.47021973]]
# 3 day input [0.14643511 0.14442799 0.15926347 ... 0.47356504 0.47180891 0.47021973]
# 3 day output [[0.4687966]]
# 4 day input [0.14442799 0.15926347 0.16214332 ... 0.47180891 0.47021973 0.46879661]
# 4 day output [[0.46752614]]
# 5 day input [0.15926347 0.16214332 0.170521   ... 0.47021973 0.46879661 0.46752614]
# 5 day output [[0.46638554]]
# 6 day input [0.16214332 0.170521   0.15699449 ... 0.46879661 0.46752614 0.46638554]
# 6 day output [[0.46534717]]
# 7 day input [0.170521   0.15699449 0.14573695 ... 0.46752614 0.46638554 0.46534717]
# 7 day output [[0.46438253]]
# ...

# %%
output
# Out:
# array([111.43583609])

# %% [markdown]
# # **Model building is Successful !**
